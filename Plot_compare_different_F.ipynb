# %%
import numpy as np
from scipy.integrate import ode
import lorenz96
import matplotlib.pyplot as plt
from settings import *

# %%
true = np.genfromtxt('x_t.txt')
true_Fperturbed = np.genfromtxt('x_t_Fperturbed.txt')
#OI
bias_OI = np.genfromtxt('OI_bias.txt')
rmse_OI = np.genfromtxt('OI_rmse.txt')

#EKF
bias_EKF = np.genfromtxt('EKF_bias.txt')
rmse_EKF = np.genfromtxt('EKF_rmse.txt')

#EnKF
bias_EnKF = np.genfromtxt('ENKF_k200_l10_modelerror0.1_bias.txt')
rmse_EnKF = np.genfromtxt('ENKF_k200_l10_modelerror0.1_rmse.txt')
print(nT)
# Out:
# 800

# %%
for i in range(N):
    pt = i
    plt.figure()
    #print(x_a_save[:,pt-1])
    #print(x_b_save[:,pt-1])
    
    plt.plot(np.arange(nT+1) * dT, true[:,pt-1], 'k+--', label=r'$x^t$')
    plt.plot(np.arange(nT+1) * dT, true_Fperturbed[:,pt-1], 'go-' , label=r'$x^p$')
    #plt.plot(np.arange(nT+1) * dT, x_a_save[:,pt-1], 'bo-' , label=r'$x^a_{' + str(pt) + '}$')
    #bias_i = (x_a_save[:,pt-1]-x_t_save[:,pt-1]).mean()
    #print("bias = ", bias_i)
    #rmse_i = np.std(x_a_save[:,pt-1]-x_t_save[:,pt-1])
    #print("rmse = ", rmse_i)
    #bias_v.append(bias_i)
    #rmse_v.append(rmse_i)
    
    
    plt.xlabel(r'$t$', size=18)
    plt.ylabel(r'$x$', size=18)
    plt.xlim(0,4)
    plt.title(r'Time series of $x_{' + str(pt) + '}$ in original and perturbed model', size=20)
    plt.legend(loc='upper right', numpoints=1, prop={'size':18})
    #plt.savefig('timeseries.png', dpi=200)
    plt.show()
    plt.close()

# %%
pt = 1
plt.figure()

plt.plot(np.arange(nT) * dT, true[:], label=r'true')
plt.plot(np.arange(nT) * dT, true_Fperturbed[:], label=r'perturbed')
#plt.plot(np.arange(nT) * dT, rmse_EnKF[:], label=r'EnKF')


plt.xlabel(r'$t$', size=18)
plt.ylabel(r'$x$', size=18)
plt.xlim(20,25)
plt.ylim(0.06,0.25)
plt.title(r'RMSE', size=20)
plt.legend(loc='upper right', numpoints=1, prop={'size':18})
#plt.savefig('Error_three_DAmethod_timeseries_2.png', dpi=200)
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b93ad5f1dc6f> in <module>()
#       2 plt.figure()
#       3
# ----> 4 plt.plot(np.arange(nT) * dT, true[:], label=r'true')
#       5 plt.plot(np.arange(nT) * dT, true_Fperturbed[:], label=r'perturbed')
#       6 #plt.plot(np.arange(nT) * dT, rmse_EnKF[:], label=r'EnKF')
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (800,) and (801, 40)

# %%
pt = i
plt.figure()

plt.plot(np.arange(nT) * dT, rmse_OI[:]-rmse_EKF[:], label=r'OI - EKF')
#plt.plot(np.arange(nT) * dT, rmse_EKF[:], label=r'EKF')
#plt.plot(np.arange(nT) * dT, rmse_EnKF[:], label=r'EnKF')


plt.xlabel(r'$t$', size=18)
plt.ylabel(r'$x$', size=18)
plt.xlim(30,35)
plt.ylim(-0.02,0.05)
plt.title(r'RMSE OI - EKF', size=20)
plt.legend(loc='upper right', numpoints=1, prop={'size':18})
#plt.savefig('Error_OI-EKF__timeseries_2.png', dpi=200)
plt.show()
plt.close()
