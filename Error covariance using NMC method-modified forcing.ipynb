# %%
#NMC method

"""
Load:
  x_a_init.txt
Save:
  x_b.txt
  x_a.txt
"""
import numpy as np
from scipy.integrate import ode
import lorenz96
import matplotlib.pyplot as plt
from settings import *
import matplotlib.pyplot as plt
import numpy.ma as ma
nT = 800

#set random seed
np.random.seed(201910)

#load true value
x_t_save = np.genfromtxt('x_t.txt')
#print(x_t_save[0])


# load initial condition
x_a_init = np.genfromtxt('x_a_init.txt')
analysis_error = 25.e-2
#x_a_init = np.genfromtxt('x_t.txt')[800] + analysis_error * np.random.randn(N)  # using nature run value plus a small error (for test purpose)
#print(x_a_init[:])

np.random.seed(20191031)
# create observations

observation_error = 25.e-2
y_o_save = np.zeros([nT+1, N])
y_o_save = x_t_save + observation_error * np.random.randn(nT+1, N)
#print(y_o_save[0])

# initial x_b: no values at the initial time (assign NaN)
x_b_save = np.full((1,N), np.nan, dtype='f8')
x_12_save = np.full((3,N), np.nan, dtype='f8')
x_24_save = np.full((5,N), np.nan, dtype='f8')
##print(x_b_save)
# initial x_a: from x_a_ens_init

x_a_save = np.array([x_a_init])
##print(x_a_save)


tt = 1

B = 0.12 * np.identity(40)#backound error covariance 
R = 0.25 * np.identity(40) #observation error covariance


while tt <= nT:
    tts = tt - 1
    Ts = tts * dT  # forecast start time
    Ta = tt  * dT  # forecast end time (DA analysis time)
    T_12 = (tt+2)  * dT
    T_24 = (tt+4)  * dT
    print('Cycle =', tt, ', Ts =', round(Ts, 10), ', Ta =', round(Ta, 10))

    #--------------
    # forecast step
    #--------------
    F = 9

    solver = ode(lorenz96.f).set_integrator('dopri5')
    solver.set_initial_value(x_a_save[tts], Ts).set_f_params(F)
    solver.integrate(Ta)
    x_b_save = np.vstack([x_b_save, [solver.y]])
    if T_12 <=nT*dT:
        solver.integrate(T_12)
        x_12_save = np.vstack([x_12_save, [solver.y]])
    if T_24 <=nT*dT:
        solver.integrate(T_24)
        x_24_save = np.vstack([x_24_save, [solver.y]])
    
    
    #solver.integrate(T_24)
    #x_24_save = np.vstack([x_24_save, [solver.y]])
    
    
    #--------------
    # analysis step
    #--------------

    # background
    #print(x_b_save[tt])
    x_b = x_b_save[tt].transpose()

    # observation

    # innovation
    y_o = y_o_save[tt].transpose()
    H = np.identity(40)
    y_b = np.dot(H, x_b)
    d = y_o - y_b

    # analysis scheme 
    K = np.dot(B, np.dot(H, np.linalg.inv(np.dot(H, np.dot(B,H))+R)))

    x_a = x_b + np.dot(K,d)
    #x_a = (x_b + y_o)/2
    
    x_a_save = np.vstack([x_a_save, x_a.transpose()])
    #print(x_a_save)
    tt += 1

# save background and analysis data
#np.savetxt('x_b.txt', x_b_save)
#np.savetxt('x_a.txt', x_a_save)
# Out:
# Cycle = 1 , Ts = 0.0 , Ta = 0.05
# Cycle = 2 , Ts = 0.05 , Ta = 0.1
# Cycle = 3 , Ts = 0.1 , Ta = 0.15
# Cycle = 4 , Ts = 0.15 , Ta = 0.2
# Cycle = 5 , Ts = 0.2 , Ta = 0.25
# Cycle = 6 , Ts = 0.25 , Ta = 0.3
# Cycle = 7 , Ts = 0.3 , Ta = 0.35
# Cycle = 8 , Ts = 0.35 , Ta = 0.4
# Cycle = 9 , Ts = 0.4 , Ta = 0.45
# Cycle = 10 , Ts = 0.45 , Ta = 0.5
# Cycle = 11 , Ts = 0.5 , Ta = 0.55
# Cycle = 12 , Ts = 0.55 , Ta = 0.6
# Cycle = 13 , Ts = 0.6 , Ta = 0.65
# Cycle = 14 , Ts = 0.65 , Ta = 0.7
# Cycle = 15 , Ts = 0.7 , Ta = 0.75
# Cycle = 16 , Ts = 0.75 , Ta = 0.8
# Cycle = 17 , Ts = 0.8 , Ta = 0.85
# Cycle = 18 , Ts = 0.85 , Ta = 0.9
# Cycle = 19 , Ts = 0.9 , Ta = 0.95
# Cycle = 20 , Ts = 0.95 , Ta = 1.0
# Cycle = 21 , Ts = 1.0 , Ta = 1.05
# Cycle = 22 , Ts = 1.05 , Ta = 1.1
# Cycle = 23 , Ts = 1.1 , Ta = 1.15
# Cycle = 24 , Ts = 1.15 , Ta = 1.2
# Cycle = 25 , Ts = 1.2 , Ta = 1.25
# Cycle = 26 , Ts = 1.25 , Ta = 1.3
# Cycle = 27 , Ts = 1.3 , Ta = 1.35
# Cycle = 28 , Ts = 1.35 , Ta = 1.4
# Cycle = 29 , Ts = 1.4 , Ta = 1.45
# Cycle = 30 , Ts = 1.45 , Ta = 1.5
# Cycle = 31 , Ts = 1.5 , Ta = 1.55
# Cycle = 32 , Ts = 1.55 , Ta = 1.6
# Cycle = 33 , Ts = 1.6 , Ta = 1.65
# Cycle = 34 , Ts = 1.65 , Ta = 1.7
# Cycle = 35 , Ts = 1.7 , Ta = 1.75
# Cycle = 36 , Ts = 1.75 , Ta = 1.8
# Cycle = 37 , Ts = 1.8 , Ta = 1.85
# Cycle = 38 , Ts = 1.85 , Ta = 1.9
# Cycle = 39 , Ts = 1.9 , Ta = 1.95
# Cycle = 40 , Ts = 1.95 , Ta = 2.0
# Cycle = 41 , Ts = 2.0 , Ta = 2.05
# Cycle = 42 , Ts = 2.05 , Ta = 2.1
# Cycle = 43 , Ts = 2.1 , Ta = 2.15
# Cycle = 44 , Ts = 2.15 , Ta = 2.2
# Cycle = 45 , Ts = 2.2 , Ta = 2.25
# Cycle = 46 , Ts = 2.25 , Ta = 2.3
# Cycle = 47 , Ts = 2.3 , Ta = 2.35
# Cycle = 48 , Ts = 2.35 , Ta = 2.4
# Cycle = 49 , Ts = 2.4 , Ta = 2.45
# Cycle = 50 , Ts = 2.45 , Ta = 2.5
# Cycle = 51 , Ts = 2.5 , Ta = 2.55
# Cycle = 52 , Ts = 2.55 , Ta = 2.6
# Cycle = 53 , Ts = 2.6 , Ta = 2.65
# Cycle = 54 , Ts = 2.65 , Ta = 2.7
# Cycle = 55 , Ts = 2.7 , Ta = 2.75
# Cycle = 56 , Ts = 2.75 , Ta = 2.8
# Cycle = 57 , Ts = 2.8 , Ta = 2.85
# Cycle = 58 , Ts = 2.85 , Ta = 2.9
# Cycle = 59 , Ts = 2.9 , Ta = 2.95
# Cycle = 60 , Ts = 2.95 , Ta = 3.0
# Cycle = 61 , Ts = 3.0 , Ta = 3.05
# Cycle = 62 , Ts = 3.05 , Ta = 3.1
# Cycle = 63 , Ts = 3.1 , Ta = 3.15
# Cycle = 64 , Ts = 3.15 , Ta = 3.2
# Cycle = 65 , Ts = 3.2 , Ta = 3.25
# Cycle = 66 , Ts = 3.25 , Ta = 3.3
# Cycle = 67 , Ts = 3.3 , Ta = 3.35
# Cycle = 68 , Ts = 3.35 , Ta = 3.4
# Cycle = 69 , Ts = 3.4 , Ta = 3.45
# Cycle = 70 , Ts = 3.45 , Ta = 3.5
# Cycle = 71 , Ts = 3.5 , Ta = 3.55
# Cycle = 72 , Ts = 3.55 , Ta = 3.6
# Cycle = 73 , Ts = 3.6 , Ta = 3.65
# Cycle = 74 , Ts = 3.65 , Ta = 3.7
# Cycle = 75 , Ts = 3.7 , Ta = 3.75
# Cycle = 76 , Ts = 3.75 , Ta = 3.8
# Cycle = 77 , Ts = 3.8 , Ta = 3.85
# Cycle = 78 , Ts = 3.85 , Ta = 3.9
# Cycle = 79 , Ts = 3.9 , Ta = 3.95
# Cycle = 80 , Ts = 3.95 , Ta = 4.0
# Cycle = 81 , Ts = 4.0 , Ta = 4.05
# Cycle = 82 , Ts = 4.05 , Ta = 4.1
# Cycle = 83 , Ts = 4.1 , Ta = 4.15
# Cycle = 84 , Ts = 4.15 , Ta = 4.2
# Cycle = 85 , Ts = 4.2 , Ta = 4.25
# Cycle = 86 , Ts = 4.25 , Ta = 4.3
# Cycle = 87 , Ts = 4.3 , Ta = 4.35
# Cycle = 88 , Ts = 4.35 , Ta = 4.4
# Cycle = 89 , Ts = 4.4 , Ta = 4.45
# Cycle = 90 , Ts = 4.45 , Ta = 4.5
# Cycle = 91 , Ts = 4.5 , Ta = 4.55
# Cycle = 92 , Ts = 4.55 , Ta = 4.6
# Cycle = 93 , Ts = 4.6 , Ta = 4.65
# Cycle = 94 , Ts = 4.65 , Ta = 4.7
# Cycle = 95 , Ts = 4.7 , Ta = 4.75
# Cycle = 96 , Ts = 4.75 , Ta = 4.8
# Cycle = 97 , Ts = 4.8 , Ta = 4.85
# Cycle = 98 , Ts = 4.85 , Ta = 4.9
# Cycle = 99 , Ts = 4.9 , Ta = 4.95
# Cycle = 100 , Ts = 4.95 , Ta = 5.0
# Cycle = 101 , Ts = 5.0 , Ta = 5.05
# Cycle = 102 , Ts = 5.05 , Ta = 5.1
# Cycle = 103 , Ts = 5.1 , Ta = 5.15
# Cycle = 104 , Ts = 5.15 , Ta = 5.2
# Cycle = 105 , Ts = 5.2 , Ta = 5.25
# Cycle = 106 , Ts = 5.25 , Ta = 5.3
# Cycle = 107 , Ts = 5.3 , Ta = 5.35
# Cycle = 108 , Ts = 5.35 , Ta = 5.4
# Cycle = 109 , Ts = 5.4 , Ta = 5.45
# Cycle = 110 , Ts = 5.45 , Ta = 5.5
# Cycle = 111 , Ts = 5.5 , Ta = 5.55
# Cycle = 112 , Ts = 5.55 , Ta = 5.6
# Cycle = 113 , Ts = 5.6 , Ta = 5.65
# Cycle = 114 , Ts = 5.65 , Ta = 5.7
# Cycle = 115 , Ts = 5.7 , Ta = 5.75
# Cycle = 116 , Ts = 5.75 , Ta = 5.8
# Cycle = 117 , Ts = 5.8 , Ta = 5.85
# Cycle = 118 , Ts = 5.85 , Ta = 5.9
# Cycle = 119 , Ts = 5.9 , Ta = 5.95
# Cycle = 120 , Ts = 5.95 , Ta = 6.0
# Cycle = 121 , Ts = 6.0 , Ta = 6.05
# Cycle = 122 , Ts = 6.05 , Ta = 6.1
# Cycle = 123 , Ts = 6.1 , Ta = 6.15
# Cycle = 124 , Ts = 6.15 , Ta = 6.2
# Cycle = 125 , Ts = 6.2 , Ta = 6.25
# Cycle = 126 , Ts = 6.25 , Ta = 6.3
# Cycle = 127 , Ts = 6.3 , Ta = 6.35
# Cycle = 128 , Ts = 6.35 , Ta = 6.4
# Cycle = 129 , Ts = 6.4 , Ta = 6.45
# Cycle = 130 , Ts = 6.45 , Ta = 6.5
# Cycle = 131 , Ts = 6.5 , Ta = 6.55
# Cycle = 132 , Ts = 6.55 , Ta = 6.6
# Cycle = 133 , Ts = 6.6 , Ta = 6.65
# Cycle = 134 , Ts = 6.65 , Ta = 6.7
# Cycle = 135 , Ts = 6.7 , Ta = 6.75
# Cycle = 136 , Ts = 6.75 , Ta = 6.8
# Cycle = 137 , Ts = 6.8 , Ta = 6.85
# Cycle = 138 , Ts = 6.85 , Ta = 6.9
# Cycle = 139 , Ts = 6.9 , Ta = 6.95
# Cycle = 140 , Ts = 6.95 , Ta = 7.0
# Cycle = 141 , Ts = 7.0 , Ta = 7.05
# Cycle = 142 , Ts = 7.05 , Ta = 7.1
# Cycle = 143 , Ts = 7.1 , Ta = 7.15
# Cycle = 144 , Ts = 7.15 , Ta = 7.2
# Cycle = 145 , Ts = 7.2 , Ta = 7.25
# Cycle = 146 , Ts = 7.25 , Ta = 7.3
# Cycle = 147 , Ts = 7.3 , Ta = 7.35
# Cycle = 148 , Ts = 7.35 , Ta = 7.4
# Cycle = 149 , Ts = 7.4 , Ta = 7.45
# Cycle = 150 , Ts = 7.45 , Ta = 7.5
# Cycle = 151 , Ts = 7.5 , Ta = 7.55
# Cycle = 152 , Ts = 7.55 , Ta = 7.6
# Cycle = 153 , Ts = 7.6 , Ta = 7.65
# Cycle = 154 , Ts = 7.65 , Ta = 7.7
# Cycle = 155 , Ts = 7.7 , Ta = 7.75
# Cycle = 156 , Ts = 7.75 , Ta = 7.8
# Cycle = 157 , Ts = 7.8 , Ta = 7.85
# Cycle = 158 , Ts = 7.85 , Ta = 7.9
# Cycle = 159 , Ts = 7.9 , Ta = 7.95
# Cycle = 160 , Ts = 7.95 , Ta = 8.0
# Cycle = 161 , Ts = 8.0 , Ta = 8.05
# Cycle = 162 , Ts = 8.05 , Ta = 8.1
# Cycle = 163 , Ts = 8.1 , Ta = 8.15
# Cycle = 164 , Ts = 8.15 , Ta = 8.2
# Cycle = 165 , Ts = 8.2 , Ta = 8.25
# Cycle = 166 , Ts = 8.25 , Ta = 8.3
# Cycle = 167 , Ts = 8.3 , Ta = 8.35
# Cycle = 168 , Ts = 8.35 , Ta = 8.4
# Cycle = 169 , Ts = 8.4 , Ta = 8.45
# Cycle = 170 , Ts = 8.45 , Ta = 8.5
# Cycle = 171 , Ts = 8.5 , Ta = 8.55
# Cycle = 172 , Ts = 8.55 , Ta = 8.6
# Cycle = 173 , Ts = 8.6 , Ta = 8.65
# Cycle = 174 , Ts = 8.65 , Ta = 8.7
# Cycle = 175 , Ts = 8.7 , Ta = 8.75
# Cycle = 176 , Ts = 8.75 , Ta = 8.8
# Cycle = 177 , Ts = 8.8 , Ta = 8.85
# Cycle = 178 , Ts = 8.85 , Ta = 8.9
# Cycle = 179 , Ts = 8.9 , Ta = 8.95
# Cycle = 180 , Ts = 8.95 , Ta = 9.0
# Cycle = 181 , Ts = 9.0 , Ta = 9.05
# Cycle = 182 , Ts = 9.05 , Ta = 9.1
# Cycle = 183 , Ts = 9.1 , Ta = 9.15
# Cycle = 184 , Ts = 9.15 , Ta = 9.2
# Cycle = 185 , Ts = 9.2 , Ta = 9.25
# Cycle = 186 , Ts = 9.25 , Ta = 9.3
# Cycle = 187 , Ts = 9.3 , Ta = 9.35
# Cycle = 188 , Ts = 9.35 , Ta = 9.4
# Cycle = 189 , Ts = 9.4 , Ta = 9.45
# Cycle = 190 , Ts = 9.45 , Ta = 9.5
# Cycle = 191 , Ts = 9.5 , Ta = 9.55
# Cycle = 192 , Ts = 9.55 , Ta = 9.6
# Cycle = 193 , Ts = 9.6 , Ta = 9.65
# Cycle = 194 , Ts = 9.65 , Ta = 9.7
# Cycle = 195 , Ts = 9.7 , Ta = 9.75
# Cycle = 196 , Ts = 9.75 , Ta = 9.8
# Cycle = 197 , Ts = 9.8 , Ta = 9.85
# Cycle = 198 , Ts = 9.85 , Ta = 9.9
# Cycle = 199 , Ts = 9.9 , Ta = 9.95
# Cycle = 200 , Ts = 9.95 , Ta = 10.0
# Cycle = 201 , Ts = 10.0 , Ta = 10.05
# Cycle = 202 , Ts = 10.05 , Ta = 10.1
# Cycle = 203 , Ts = 10.1 , Ta = 10.15
# Cycle = 204 , Ts = 10.15 , Ta = 10.2
# Cycle = 205 , Ts = 10.2 , Ta = 10.25
# Cycle = 206 , Ts = 10.25 , Ta = 10.3
# Cycle = 207 , Ts = 10.3 , Ta = 10.35
# Cycle = 208 , Ts = 10.35 , Ta = 10.4
# Cycle = 209 , Ts = 10.4 , Ta = 10.45
# Cycle = 210 , Ts = 10.45 , Ta = 10.5
# Cycle = 211 , Ts = 10.5 , Ta = 10.55
# Cycle = 212 , Ts = 10.55 , Ta = 10.6
# Cycle = 213 , Ts = 10.6 , Ta = 10.65
# Cycle = 214 , Ts = 10.65 , Ta = 10.7
# Cycle = 215 , Ts = 10.7 , Ta = 10.75
# Cycle = 216 , Ts = 10.75 , Ta = 10.8
# Cycle = 217 , Ts = 10.8 , Ta = 10.85
# Cycle = 218 , Ts = 10.85 , Ta = 10.9
# Cycle = 219 , Ts = 10.9 , Ta = 10.95
# Cycle = 220 , Ts = 10.95 , Ta = 11.0
# Cycle = 221 , Ts = 11.0 , Ta = 11.05
# Cycle = 222 , Ts = 11.05 , Ta = 11.1
# Cycle = 223 , Ts = 11.1 , Ta = 11.15
# Cycle = 224 , Ts = 11.15 , Ta = 11.2
# Cycle = 225 , Ts = 11.2 , Ta = 11.25
# Cycle = 226 , Ts = 11.25 , Ta = 11.3
# Cycle = 227 , Ts = 11.3 , Ta = 11.35
# Cycle = 228 , Ts = 11.35 , Ta = 11.4
# Cycle = 229 , Ts = 11.4 , Ta = 11.45
# Cycle = 230 , Ts = 11.45 , Ta = 11.5
# Cycle = 231 , Ts = 11.5 , Ta = 11.55
# Cycle = 232 , Ts = 11.55 , Ta = 11.6
# Cycle = 233 , Ts = 11.6 , Ta = 11.65
# Cycle = 234 , Ts = 11.65 , Ta = 11.7
# Cycle = 235 , Ts = 11.7 , Ta = 11.75
# Cycle = 236 , Ts = 11.75 , Ta = 11.8
# Cycle = 237 , Ts = 11.8 , Ta = 11.85
# Cycle = 238 , Ts = 11.85 , Ta = 11.9
# Cycle = 239 , Ts = 11.9 , Ta = 11.95
# Cycle = 240 , Ts = 11.95 , Ta = 12.0
# Cycle = 241 , Ts = 12.0 , Ta = 12.05
# Cycle = 242 , Ts = 12.05 , Ta = 12.1
# Cycle = 243 , Ts = 12.1 , Ta = 12.15
# Cycle = 244 , Ts = 12.15 , Ta = 12.2
# Cycle = 245 , Ts = 12.2 , Ta = 12.25
# Cycle = 246 , Ts = 12.25 , Ta = 12.3
# Cycle = 247 , Ts = 12.3 , Ta = 12.35
# Cycle = 248 , Ts = 12.35 , Ta = 12.4
# Cycle = 249 , Ts = 12.4 , Ta = 12.45
# Cycle = 250 , Ts = 12.45 , Ta = 12.5
# Cycle = 251 , Ts = 12.5 , Ta = 12.55
# Cycle = 252 , Ts = 12.55 , Ta = 12.6
# Cycle = 253 , Ts = 12.6 , Ta = 12.65
# Cycle = 254 , Ts = 12.65 , Ta = 12.7
# Cycle = 255 , Ts = 12.7 , Ta = 12.75
# Cycle = 256 , Ts = 12.75 , Ta = 12.8
# Cycle = 257 , Ts = 12.8 , Ta = 12.85
# Cycle = 258 , Ts = 12.85 , Ta = 12.9
# Cycle = 259 , Ts = 12.9 , Ta = 12.95
# Cycle = 260 , Ts = 12.95 , Ta = 13.0
# Cycle = 261 , Ts = 13.0 , Ta = 13.05
# Cycle = 262 , Ts = 13.05 , Ta = 13.1
# Cycle = 263 , Ts = 13.1 , Ta = 13.15
# Cycle = 264 , Ts = 13.15 , Ta = 13.2
# Cycle = 265 , Ts = 13.2 , Ta = 13.25
# Cycle = 266 , Ts = 13.25 , Ta = 13.3
# Cycle = 267 , Ts = 13.3 , Ta = 13.35
# Cycle = 268 , Ts = 13.35 , Ta = 13.4
# Cycle = 269 , Ts = 13.4 , Ta = 13.45
# Cycle = 270 , Ts = 13.45 , Ta = 13.5
# Cycle = 271 , Ts = 13.5 , Ta = 13.55
# Cycle = 272 , Ts = 13.55 , Ta = 13.6
# Cycle = 273 , Ts = 13.6 , Ta = 13.65
# Cycle = 274 , Ts = 13.65 , Ta = 13.7
# Cycle = 275 , Ts = 13.7 , Ta = 13.75
# Cycle = 276 , Ts = 13.75 , Ta = 13.8
# Cycle = 277 , Ts = 13.8 , Ta = 13.85
# Cycle = 278 , Ts = 13.85 , Ta = 13.9
# Cycle = 279 , Ts = 13.9 , Ta = 13.95
# Cycle = 280 , Ts = 13.95 , Ta = 14.0
# Cycle = 281 , Ts = 14.0 , Ta = 14.05
# Cycle = 282 , Ts = 14.05 , Ta = 14.1
# Cycle = 283 , Ts = 14.1 , Ta = 14.15
# Cycle = 284 , Ts = 14.15 , Ta = 14.2
# Cycle = 285 , Ts = 14.2 , Ta = 14.25
# Cycle = 286 , Ts = 14.25 , Ta = 14.3
# Cycle = 287 , Ts = 14.3 , Ta = 14.35
# Cycle = 288 , Ts = 14.35 , Ta = 14.4
# Cycle = 289 , Ts = 14.4 , Ta = 14.45
# Cycle = 290 , Ts = 14.45 , Ta = 14.5
# Cycle = 291 , Ts = 14.5 , Ta = 14.55
# Cycle = 292 , Ts = 14.55 , Ta = 14.6
# Cycle = 293 , Ts = 14.6 , Ta = 14.65
# Cycle = 294 , Ts = 14.65 , Ta = 14.7
# Cycle = 295 , Ts = 14.7 , Ta = 14.75
# Cycle = 296 , Ts = 14.75 , Ta = 14.8
# Cycle = 297 , Ts = 14.8 , Ta = 14.85
# Cycle = 298 , Ts = 14.85 , Ta = 14.9
# Cycle = 299 , Ts = 14.9 , Ta = 14.95
# Cycle = 300 , Ts = 14.95 , Ta = 15.0
# Cycle = 301 , Ts = 15.0 , Ta = 15.05
# Cycle = 302 , Ts = 15.05 , Ta = 15.1
# Cycle = 303 , Ts = 15.1 , Ta = 15.15
# Cycle = 304 , Ts = 15.15 , Ta = 15.2
# Cycle = 305 , Ts = 15.2 , Ta = 15.25
# Cycle = 306 , Ts = 15.25 , Ta = 15.3
# Cycle = 307 , Ts = 15.3 , Ta = 15.35
# Cycle = 308 , Ts = 15.35 , Ta = 15.4
# Cycle = 309 , Ts = 15.4 , Ta = 15.45
# Cycle = 310 , Ts = 15.45 , Ta = 15.5
# Cycle = 311 , Ts = 15.5 , Ta = 15.55
# Cycle = 312 , Ts = 15.55 , Ta = 15.6
# Cycle = 313 , Ts = 15.6 , Ta = 15.65
# Cycle = 314 , Ts = 15.65 , Ta = 15.7
# Cycle = 315 , Ts = 15.7 , Ta = 15.75
# Cycle = 316 , Ts = 15.75 , Ta = 15.8
# Cycle = 317 , Ts = 15.8 , Ta = 15.85
# Cycle = 318 , Ts = 15.85 , Ta = 15.9
# Cycle = 319 , Ts = 15.9 , Ta = 15.95
# Cycle = 320 , Ts = 15.95 , Ta = 16.0
# Cycle = 321 , Ts = 16.0 , Ta = 16.05
# Cycle = 322 , Ts = 16.05 , Ta = 16.1
# Cycle = 323 , Ts = 16.1 , Ta = 16.15
# Cycle = 324 , Ts = 16.15 , Ta = 16.2
# Cycle = 325 , Ts = 16.2 , Ta = 16.25
# Cycle = 326 , Ts = 16.25 , Ta = 16.3
# Cycle = 327 , Ts = 16.3 , Ta = 16.35
# Cycle = 328 , Ts = 16.35 , Ta = 16.4
# Cycle = 329 , Ts = 16.4 , Ta = 16.45
# Cycle = 330 , Ts = 16.45 , Ta = 16.5
# Cycle = 331 , Ts = 16.5 , Ta = 16.55
# Cycle = 332 , Ts = 16.55 , Ta = 16.6
# Cycle = 333 , Ts = 16.6 , Ta = 16.65
# Cycle = 334 , Ts = 16.65 , Ta = 16.7
# Cycle = 335 , Ts = 16.7 , Ta = 16.75
# Cycle = 336 , Ts = 16.75 , Ta = 16.8
# Cycle = 337 , Ts = 16.8 , Ta = 16.85
# Cycle = 338 , Ts = 16.85 , Ta = 16.9
# Cycle = 339 , Ts = 16.9 , Ta = 16.95
# Cycle = 340 , Ts = 16.95 , Ta = 17.0
# Cycle = 341 , Ts = 17.0 , Ta = 17.05
# Cycle = 342 , Ts = 17.05 , Ta = 17.1
# Cycle = 343 , Ts = 17.1 , Ta = 17.15
# Cycle = 344 , Ts = 17.15 , Ta = 17.2
# Cycle = 345 , Ts = 17.2 , Ta = 17.25
# Cycle = 346 , Ts = 17.25 , Ta = 17.3
# Cycle = 347 , Ts = 17.3 , Ta = 17.35
# Cycle = 348 , Ts = 17.35 , Ta = 17.4
# Cycle = 349 , Ts = 17.4 , Ta = 17.45
# Cycle = 350 , Ts = 17.45 , Ta = 17.5
# Cycle = 351 , Ts = 17.5 , Ta = 17.55
# Cycle = 352 , Ts = 17.55 , Ta = 17.6
# Cycle = 353 , Ts = 17.6 , Ta = 17.65
# Cycle = 354 , Ts = 17.65 , Ta = 17.7
# Cycle = 355 , Ts = 17.7 , Ta = 17.75
# Cycle = 356 , Ts = 17.75 , Ta = 17.8
# Cycle = 357 , Ts = 17.8 , Ta = 17.85
# Cycle = 358 , Ts = 17.85 , Ta = 17.9
# Cycle = 359 , Ts = 17.9 , Ta = 17.95
# Cycle = 360 , Ts = 17.95 , Ta = 18.0
# Cycle = 361 , Ts = 18.0 , Ta = 18.05
# Cycle = 362 , Ts = 18.05 , Ta = 18.1
# Cycle = 363 , Ts = 18.1 , Ta = 18.15
# Cycle = 364 , Ts = 18.15 , Ta = 18.2
# Cycle = 365 , Ts = 18.2 , Ta = 18.25
# Cycle = 366 , Ts = 18.25 , Ta = 18.3
# Cycle = 367 , Ts = 18.3 , Ta = 18.35
# Cycle = 368 , Ts = 18.35 , Ta = 18.4
# Cycle = 369 , Ts = 18.4 , Ta = 18.45
# Cycle = 370 , Ts = 18.45 , Ta = 18.5
# Cycle = 371 , Ts = 18.5 , Ta = 18.55
# Cycle = 372 , Ts = 18.55 , Ta = 18.6
# Cycle = 373 , Ts = 18.6 , Ta = 18.65
# Cycle = 374 , Ts = 18.65 , Ta = 18.7
# Cycle = 375 , Ts = 18.7 , Ta = 18.75
# Cycle = 376 , Ts = 18.75 , Ta = 18.8
# Cycle = 377 , Ts = 18.8 , Ta = 18.85
# Cycle = 378 , Ts = 18.85 , Ta = 18.9
# Cycle = 379 , Ts = 18.9 , Ta = 18.95
# Cycle = 380 , Ts = 18.95 , Ta = 19.0
# Cycle = 381 , Ts = 19.0 , Ta = 19.05
# Cycle = 382 , Ts = 19.05 , Ta = 19.1
# Cycle = 383 , Ts = 19.1 , Ta = 19.15
# Cycle = 384 , Ts = 19.15 , Ta = 19.2
# Cycle = 385 , Ts = 19.2 , Ta = 19.25
# Cycle = 386 , Ts = 19.25 , Ta = 19.3
# Cycle = 387 , Ts = 19.3 , Ta = 19.35
# Cycle = 388 , Ts = 19.35 , Ta = 19.4
# Cycle = 389 , Ts = 19.4 , Ta = 19.45
# Cycle = 390 , Ts = 19.45 , Ta = 19.5
# Cycle = 391 , Ts = 19.5 , Ta = 19.55
# Cycle = 392 , Ts = 19.55 , Ta = 19.6
# Cycle = 393 , Ts = 19.6 , Ta = 19.65
# Cycle = 394 , Ts = 19.65 , Ta = 19.7
# Cycle = 395 , Ts = 19.7 , Ta = 19.75
# Cycle = 396 , Ts = 19.75 , Ta = 19.8
# Cycle = 397 , Ts = 19.8 , Ta = 19.85
# Cycle = 398 , Ts = 19.85 , Ta = 19.9
# Cycle = 399 , Ts = 19.9 , Ta = 19.95
# Cycle = 400 , Ts = 19.95 , Ta = 20.0
# Cycle = 401 , Ts = 20.0 , Ta = 20.05
# Cycle = 402 , Ts = 20.05 , Ta = 20.1
# Cycle = 403 , Ts = 20.1 , Ta = 20.15
# Cycle = 404 , Ts = 20.15 , Ta = 20.2
# Cycle = 405 , Ts = 20.2 , Ta = 20.25
# Cycle = 406 , Ts = 20.25 , Ta = 20.3
# Cycle = 407 , Ts = 20.3 , Ta = 20.35
# Cycle = 408 , Ts = 20.35 , Ta = 20.4
# Cycle = 409 , Ts = 20.4 , Ta = 20.45
# Cycle = 410 , Ts = 20.45 , Ta = 20.5
# Cycle = 411 , Ts = 20.5 , Ta = 20.55
# Cycle = 412 , Ts = 20.55 , Ta = 20.6
# Cycle = 413 , Ts = 20.6 , Ta = 20.65
# Cycle = 414 , Ts = 20.65 , Ta = 20.7
# Cycle = 415 , Ts = 20.7 , Ta = 20.75
# Cycle = 416 , Ts = 20.75 , Ta = 20.8
# Cycle = 417 , Ts = 20.8 , Ta = 20.85
# Cycle = 418 , Ts = 20.85 , Ta = 20.9
# Cycle = 419 , Ts = 20.9 , Ta = 20.95
# Cycle = 420 , Ts = 20.95 , Ta = 21.0
# Cycle = 421 , Ts = 21.0 , Ta = 21.05
# Cycle = 422 , Ts = 21.05 , Ta = 21.1
# Cycle = 423 , Ts = 21.1 , Ta = 21.15
# Cycle = 424 , Ts = 21.15 , Ta = 21.2
# Cycle = 425 , Ts = 21.2 , Ta = 21.25
# Cycle = 426 , Ts = 21.25 , Ta = 21.3
# Cycle = 427 , Ts = 21.3 , Ta = 21.35
# Cycle = 428 , Ts = 21.35 , Ta = 21.4
# Cycle = 429 , Ts = 21.4 , Ta = 21.45
# Cycle = 430 , Ts = 21.45 , Ta = 21.5
# Cycle = 431 , Ts = 21.5 , Ta = 21.55
# Cycle = 432 , Ts = 21.55 , Ta = 21.6
# Cycle = 433 , Ts = 21.6 , Ta = 21.65
# Cycle = 434 , Ts = 21.65 , Ta = 21.7
# Cycle = 435 , Ts = 21.7 , Ta = 21.75
# Cycle = 436 , Ts = 21.75 , Ta = 21.8
# Cycle = 437 , Ts = 21.8 , Ta = 21.85
# Cycle = 438 , Ts = 21.85 , Ta = 21.9
# Cycle = 439 , Ts = 21.9 , Ta = 21.95
# Cycle = 440 , Ts = 21.95 , Ta = 22.0
# Cycle = 441 , Ts = 22.0 , Ta = 22.05
# Cycle = 442 , Ts = 22.05 , Ta = 22.1
# Cycle = 443 , Ts = 22.1 , Ta = 22.15
# Cycle = 444 , Ts = 22.15 , Ta = 22.2
# Cycle = 445 , Ts = 22.2 , Ta = 22.25
# Cycle = 446 , Ts = 22.25 , Ta = 22.3
# Cycle = 447 , Ts = 22.3 , Ta = 22.35
# Cycle = 448 , Ts = 22.35 , Ta = 22.4
# Cycle = 449 , Ts = 22.4 , Ta = 22.45
# Cycle = 450 , Ts = 22.45 , Ta = 22.5
# Cycle = 451 , Ts = 22.5 , Ta = 22.55
# Cycle = 452 , Ts = 22.55 , Ta = 22.6
# Cycle = 453 , Ts = 22.6 , Ta = 22.65
# Cycle = 454 , Ts = 22.65 , Ta = 22.7
# Cycle = 455 , Ts = 22.7 , Ta = 22.75
# Cycle = 456 , Ts = 22.75 , Ta = 22.8
# Cycle = 457 , Ts = 22.8 , Ta = 22.85
# Cycle = 458 , Ts = 22.85 , Ta = 22.9
# Cycle = 459 , Ts = 22.9 , Ta = 22.95
# Cycle = 460 , Ts = 22.95 , Ta = 23.0
# Cycle = 461 , Ts = 23.0 , Ta = 23.05
# Cycle = 462 , Ts = 23.05 , Ta = 23.1
# Cycle = 463 , Ts = 23.1 , Ta = 23.15
# Cycle = 464 , Ts = 23.15 , Ta = 23.2
# Cycle = 465 , Ts = 23.2 , Ta = 23.25
# Cycle = 466 , Ts = 23.25 , Ta = 23.3
# Cycle = 467 , Ts = 23.3 , Ta = 23.35
# Cycle = 468 , Ts = 23.35 , Ta = 23.4
# Cycle = 469 , Ts = 23.4 , Ta = 23.45
# Cycle = 470 , Ts = 23.45 , Ta = 23.5
# Cycle = 471 , Ts = 23.5 , Ta = 23.55
# Cycle = 472 , Ts = 23.55 , Ta = 23.6
# Cycle = 473 , Ts = 23.6 , Ta = 23.65
# Cycle = 474 , Ts = 23.65 , Ta = 23.7
# Cycle = 475 , Ts = 23.7 , Ta = 23.75
# Cycle = 476 , Ts = 23.75 , Ta = 23.8
# Cycle = 477 , Ts = 23.8 , Ta = 23.85
# Cycle = 478 , Ts = 23.85 , Ta = 23.9
# Cycle = 479 , Ts = 23.9 , Ta = 23.95
# Cycle = 480 , Ts = 23.95 , Ta = 24.0
# Cycle = 481 , Ts = 24.0 , Ta = 24.05
# Cycle = 482 , Ts = 24.05 , Ta = 24.1
# Cycle = 483 , Ts = 24.1 , Ta = 24.15
# Cycle = 484 , Ts = 24.15 , Ta = 24.2
# Cycle = 485 , Ts = 24.2 , Ta = 24.25
# Cycle = 486 , Ts = 24.25 , Ta = 24.3
# Cycle = 487 , Ts = 24.3 , Ta = 24.35
# Cycle = 488 , Ts = 24.35 , Ta = 24.4
# Cycle = 489 , Ts = 24.4 , Ta = 24.45
# Cycle = 490 , Ts = 24.45 , Ta = 24.5
# Cycle = 491 , Ts = 24.5 , Ta = 24.55
# Cycle = 492 , Ts = 24.55 , Ta = 24.6
# Cycle = 493 , Ts = 24.6 , Ta = 24.65
# Cycle = 494 , Ts = 24.65 , Ta = 24.7
# Cycle = 495 , Ts = 24.7 , Ta = 24.75
# Cycle = 496 , Ts = 24.75 , Ta = 24.8
# Cycle = 497 , Ts = 24.8 , Ta = 24.85
# Cycle = 498 , Ts = 24.85 , Ta = 24.9
# Cycle = 499 , Ts = 24.9 , Ta = 24.95
# Cycle = 500 , Ts = 24.95 , Ta = 25.0
# Cycle = 501 , Ts = 25.0 , Ta = 25.05
# Cycle = 502 , Ts = 25.05 , Ta = 25.1
# Cycle = 503 , Ts = 25.1 , Ta = 25.15
# Cycle = 504 , Ts = 25.15 , Ta = 25.2
# Cycle = 505 , Ts = 25.2 , Ta = 25.25
# Cycle = 506 , Ts = 25.25 , Ta = 25.3
# Cycle = 507 , Ts = 25.3 , Ta = 25.35
# Cycle = 508 , Ts = 25.35 , Ta = 25.4
# Cycle = 509 , Ts = 25.4 , Ta = 25.45
# Cycle = 510 , Ts = 25.45 , Ta = 25.5
# Cycle = 511 , Ts = 25.5 , Ta = 25.55
# Cycle = 512 , Ts = 25.55 , Ta = 25.6
# Cycle = 513 , Ts = 25.6 , Ta = 25.65
# Cycle = 514 , Ts = 25.65 , Ta = 25.7
# Cycle = 515 , Ts = 25.7 , Ta = 25.75
# Cycle = 516 , Ts = 25.75 , Ta = 25.8
# Cycle = 517 , Ts = 25.8 , Ta = 25.85
# Cycle = 518 , Ts = 25.85 , Ta = 25.9
# Cycle = 519 , Ts = 25.9 , Ta = 25.95
# Cycle = 520 , Ts = 25.95 , Ta = 26.0
# Cycle = 521 , Ts = 26.0 , Ta = 26.05
# Cycle = 522 , Ts = 26.05 , Ta = 26.1
# Cycle = 523 , Ts = 26.1 , Ta = 26.15
# Cycle = 524 , Ts = 26.15 , Ta = 26.2
# Cycle = 525 , Ts = 26.2 , Ta = 26.25
# Cycle = 526 , Ts = 26.25 , Ta = 26.3
# Cycle = 527 , Ts = 26.3 , Ta = 26.35
# Cycle = 528 , Ts = 26.35 , Ta = 26.4
# Cycle = 529 , Ts = 26.4 , Ta = 26.45
# Cycle = 530 , Ts = 26.45 , Ta = 26.5
# Cycle = 531 , Ts = 26.5 , Ta = 26.55
# Cycle = 532 , Ts = 26.55 , Ta = 26.6
# Cycle = 533 , Ts = 26.6 , Ta = 26.65
# Cycle = 534 , Ts = 26.65 , Ta = 26.7
# Cycle = 535 , Ts = 26.7 , Ta = 26.75
# Cycle = 536 , Ts = 26.75 , Ta = 26.8
# Cycle = 537 , Ts = 26.8 , Ta = 26.85
# Cycle = 538 , Ts = 26.85 , Ta = 26.9
# Cycle = 539 , Ts = 26.9 , Ta = 26.95
# Cycle = 540 , Ts = 26.95 , Ta = 27.0
# Cycle = 541 , Ts = 27.0 , Ta = 27.05
# Cycle = 542 , Ts = 27.05 , Ta = 27.1
# Cycle = 543 , Ts = 27.1 , Ta = 27.15
# Cycle = 544 , Ts = 27.15 , Ta = 27.2
# Cycle = 545 , Ts = 27.2 , Ta = 27.25
# Cycle = 546 , Ts = 27.25 , Ta = 27.3
# Cycle = 547 , Ts = 27.3 , Ta = 27.35
# Cycle = 548 , Ts = 27.35 , Ta = 27.4
# Cycle = 549 , Ts = 27.4 , Ta = 27.45
# Cycle = 550 , Ts = 27.45 , Ta = 27.5
# Cycle = 551 , Ts = 27.5 , Ta = 27.55
# Cycle = 552 , Ts = 27.55 , Ta = 27.6
# Cycle = 553 , Ts = 27.6 , Ta = 27.65
# Cycle = 554 , Ts = 27.65 , Ta = 27.7
# Cycle = 555 , Ts = 27.7 , Ta = 27.75
# Cycle = 556 , Ts = 27.75 , Ta = 27.8
# Cycle = 557 , Ts = 27.8 , Ta = 27.85
# Cycle = 558 , Ts = 27.85 , Ta = 27.9
# Cycle = 559 , Ts = 27.9 , Ta = 27.95
# Cycle = 560 , Ts = 27.95 , Ta = 28.0
# Cycle = 561 , Ts = 28.0 , Ta = 28.05
# Cycle = 562 , Ts = 28.05 , Ta = 28.1
# Cycle = 563 , Ts = 28.1 , Ta = 28.15
# Cycle = 564 , Ts = 28.15 , Ta = 28.2
# Cycle = 565 , Ts = 28.2 , Ta = 28.25
# Cycle = 566 , Ts = 28.25 , Ta = 28.3
# Cycle = 567 , Ts = 28.3 , Ta = 28.35
# Cycle = 568 , Ts = 28.35 , Ta = 28.4
# Cycle = 569 , Ts = 28.4 , Ta = 28.45
# Cycle = 570 , Ts = 28.45 , Ta = 28.5
# Cycle = 571 , Ts = 28.5 , Ta = 28.55
# Cycle = 572 , Ts = 28.55 , Ta = 28.6
# Cycle = 573 , Ts = 28.6 , Ta = 28.65
# Cycle = 574 , Ts = 28.65 , Ta = 28.7
# Cycle = 575 , Ts = 28.7 , Ta = 28.75
# Cycle = 576 , Ts = 28.75 , Ta = 28.8
# Cycle = 577 , Ts = 28.8 , Ta = 28.85
# Cycle = 578 , Ts = 28.85 , Ta = 28.9
# Cycle = 579 , Ts = 28.9 , Ta = 28.95
# Cycle = 580 , Ts = 28.95 , Ta = 29.0
# Cycle = 581 , Ts = 29.0 , Ta = 29.05
# Cycle = 582 , Ts = 29.05 , Ta = 29.1
# Cycle = 583 , Ts = 29.1 , Ta = 29.15
# Cycle = 584 , Ts = 29.15 , Ta = 29.2
# Cycle = 585 , Ts = 29.2 , Ta = 29.25
# Cycle = 586 , Ts = 29.25 , Ta = 29.3
# Cycle = 587 , Ts = 29.3 , Ta = 29.35
# Cycle = 588 , Ts = 29.35 , Ta = 29.4
# Cycle = 589 , Ts = 29.4 , Ta = 29.45
# Cycle = 590 , Ts = 29.45 , Ta = 29.5
# Cycle = 591 , Ts = 29.5 , Ta = 29.55
# Cycle = 592 , Ts = 29.55 , Ta = 29.6
# Cycle = 593 , Ts = 29.6 , Ta = 29.65
# Cycle = 594 , Ts = 29.65 , Ta = 29.7
# Cycle = 595 , Ts = 29.7 , Ta = 29.75
# Cycle = 596 , Ts = 29.75 , Ta = 29.8
# Cycle = 597 , Ts = 29.8 , Ta = 29.85
# Cycle = 598 , Ts = 29.85 , Ta = 29.9
# Cycle = 599 , Ts = 29.9 , Ta = 29.95
# Cycle = 600 , Ts = 29.95 , Ta = 30.0
# Cycle = 601 , Ts = 30.0 , Ta = 30.05
# Cycle = 602 , Ts = 30.05 , Ta = 30.1
# Cycle = 603 , Ts = 30.1 , Ta = 30.15
# Cycle = 604 , Ts = 30.15 , Ta = 30.2
# Cycle = 605 , Ts = 30.2 , Ta = 30.25
# Cycle = 606 , Ts = 30.25 , Ta = 30.3
# Cycle = 607 , Ts = 30.3 , Ta = 30.35
# Cycle = 608 , Ts = 30.35 , Ta = 30.4
# Cycle = 609 , Ts = 30.4 , Ta = 30.45
# Cycle = 610 , Ts = 30.45 , Ta = 30.5
# Cycle = 611 , Ts = 30.5 , Ta = 30.55
# Cycle = 612 , Ts = 30.55 , Ta = 30.6
# Cycle = 613 , Ts = 30.6 , Ta = 30.65
# Cycle = 614 , Ts = 30.65 , Ta = 30.7
# Cycle = 615 , Ts = 30.7 , Ta = 30.75
# Cycle = 616 , Ts = 30.75 , Ta = 30.8
# Cycle = 617 , Ts = 30.8 , Ta = 30.85
# Cycle = 618 , Ts = 30.85 , Ta = 30.9
# Cycle = 619 , Ts = 30.9 , Ta = 30.95
# Cycle = 620 , Ts = 30.95 , Ta = 31.0
# Cycle = 621 , Ts = 31.0 , Ta = 31.05
# Cycle = 622 , Ts = 31.05 , Ta = 31.1
# Cycle = 623 , Ts = 31.1 , Ta = 31.15
# Cycle = 624 , Ts = 31.15 , Ta = 31.2
# Cycle = 625 , Ts = 31.2 , Ta = 31.25
# Cycle = 626 , Ts = 31.25 , Ta = 31.3
# Cycle = 627 , Ts = 31.3 , Ta = 31.35
# Cycle = 628 , Ts = 31.35 , Ta = 31.4
# Cycle = 629 , Ts = 31.4 , Ta = 31.45
# Cycle = 630 , Ts = 31.45 , Ta = 31.5
# Cycle = 631 , Ts = 31.5 , Ta = 31.55
# Cycle = 632 , Ts = 31.55 , Ta = 31.6
# Cycle = 633 , Ts = 31.6 , Ta = 31.65
# Cycle = 634 , Ts = 31.65 , Ta = 31.7
# Cycle = 635 , Ts = 31.7 , Ta = 31.75
# Cycle = 636 , Ts = 31.75 , Ta = 31.8
# Cycle = 637 , Ts = 31.8 , Ta = 31.85
# Cycle = 638 , Ts = 31.85 , Ta = 31.9
# Cycle = 639 , Ts = 31.9 , Ta = 31.95
# Cycle = 640 , Ts = 31.95 , Ta = 32.0
# Cycle = 641 , Ts = 32.0 , Ta = 32.05
# Cycle = 642 , Ts = 32.05 , Ta = 32.1
# Cycle = 643 , Ts = 32.1 , Ta = 32.15
# Cycle = 644 , Ts = 32.15 , Ta = 32.2
# Cycle = 645 , Ts = 32.2 , Ta = 32.25
# Cycle = 646 , Ts = 32.25 , Ta = 32.3
# Cycle = 647 , Ts = 32.3 , Ta = 32.35
# Cycle = 648 , Ts = 32.35 , Ta = 32.4
# Cycle = 649 , Ts = 32.4 , Ta = 32.45
# Cycle = 650 , Ts = 32.45 , Ta = 32.5
# Cycle = 651 , Ts = 32.5 , Ta = 32.55
# Cycle = 652 , Ts = 32.55 , Ta = 32.6
# Cycle = 653 , Ts = 32.6 , Ta = 32.65
# Cycle = 654 , Ts = 32.65 , Ta = 32.7
# Cycle = 655 , Ts = 32.7 , Ta = 32.75
# Cycle = 656 , Ts = 32.75 , Ta = 32.8
# Cycle = 657 , Ts = 32.8 , Ta = 32.85
# Cycle = 658 , Ts = 32.85 , Ta = 32.9
# Cycle = 659 , Ts = 32.9 , Ta = 32.95
# Cycle = 660 , Ts = 32.95 , Ta = 33.0
# Cycle = 661 , Ts = 33.0 , Ta = 33.05
# Cycle = 662 , Ts = 33.05 , Ta = 33.1
# Cycle = 663 , Ts = 33.1 , Ta = 33.15
# Cycle = 664 , Ts = 33.15 , Ta = 33.2
# Cycle = 665 , Ts = 33.2 , Ta = 33.25
# Cycle = 666 , Ts = 33.25 , Ta = 33.3
# Cycle = 667 , Ts = 33.3 , Ta = 33.35
# Cycle = 668 , Ts = 33.35 , Ta = 33.4
# Cycle = 669 , Ts = 33.4 , Ta = 33.45
# Cycle = 670 , Ts = 33.45 , Ta = 33.5
# Cycle = 671 , Ts = 33.5 , Ta = 33.55
# Cycle = 672 , Ts = 33.55 , Ta = 33.6
# Cycle = 673 , Ts = 33.6 , Ta = 33.65
# Cycle = 674 , Ts = 33.65 , Ta = 33.7
# Cycle = 675 , Ts = 33.7 , Ta = 33.75
# Cycle = 676 , Ts = 33.75 , Ta = 33.8
# Cycle = 677 , Ts = 33.8 , Ta = 33.85
# Cycle = 678 , Ts = 33.85 , Ta = 33.9
# Cycle = 679 , Ts = 33.9 , Ta = 33.95
# Cycle = 680 , Ts = 33.95 , Ta = 34.0
# Cycle = 681 , Ts = 34.0 , Ta = 34.05
# Cycle = 682 , Ts = 34.05 , Ta = 34.1
# Cycle = 683 , Ts = 34.1 , Ta = 34.15
# Cycle = 684 , Ts = 34.15 , Ta = 34.2
# Cycle = 685 , Ts = 34.2 , Ta = 34.25
# Cycle = 686 , Ts = 34.25 , Ta = 34.3
# Cycle = 687 , Ts = 34.3 , Ta = 34.35
# Cycle = 688 , Ts = 34.35 , Ta = 34.4
# Cycle = 689 , Ts = 34.4 , Ta = 34.45
# Cycle = 690 , Ts = 34.45 , Ta = 34.5
# Cycle = 691 , Ts = 34.5 , Ta = 34.55
# Cycle = 692 , Ts = 34.55 , Ta = 34.6
# Cycle = 693 , Ts = 34.6 , Ta = 34.65
# Cycle = 694 , Ts = 34.65 , Ta = 34.7
# Cycle = 695 , Ts = 34.7 , Ta = 34.75
# Cycle = 696 , Ts = 34.75 , Ta = 34.8
# Cycle = 697 , Ts = 34.8 , Ta = 34.85
# Cycle = 698 , Ts = 34.85 , Ta = 34.9
# Cycle = 699 , Ts = 34.9 , Ta = 34.95
# Cycle = 700 , Ts = 34.95 , Ta = 35.0
# Cycle = 701 , Ts = 35.0 , Ta = 35.05
# Cycle = 702 , Ts = 35.05 , Ta = 35.1
# Cycle = 703 , Ts = 35.1 , Ta = 35.15
# Cycle = 704 , Ts = 35.15 , Ta = 35.2
# Cycle = 705 , Ts = 35.2 , Ta = 35.25
# Cycle = 706 , Ts = 35.25 , Ta = 35.3
# Cycle = 707 , Ts = 35.3 , Ta = 35.35
# Cycle = 708 , Ts = 35.35 , Ta = 35.4
# Cycle = 709 , Ts = 35.4 , Ta = 35.45
# Cycle = 710 , Ts = 35.45 , Ta = 35.5
# Cycle = 711 , Ts = 35.5 , Ta = 35.55
# Cycle = 712 , Ts = 35.55 , Ta = 35.6
# Cycle = 713 , Ts = 35.6 , Ta = 35.65
# Cycle = 714 , Ts = 35.65 , Ta = 35.7
# Cycle = 715 , Ts = 35.7 , Ta = 35.75
# Cycle = 716 , Ts = 35.75 , Ta = 35.8
# Cycle = 717 , Ts = 35.8 , Ta = 35.85
# Cycle = 718 , Ts = 35.85 , Ta = 35.9
# Cycle = 719 , Ts = 35.9 , Ta = 35.95
# Cycle = 720 , Ts = 35.95 , Ta = 36.0
# Cycle = 721 , Ts = 36.0 , Ta = 36.05
# Cycle = 722 , Ts = 36.05 , Ta = 36.1
# Cycle = 723 , Ts = 36.1 , Ta = 36.15
# Cycle = 724 , Ts = 36.15 , Ta = 36.2
# Cycle = 725 , Ts = 36.2 , Ta = 36.25
# Cycle = 726 , Ts = 36.25 , Ta = 36.3
# Cycle = 727 , Ts = 36.3 , Ta = 36.35
# Cycle = 728 , Ts = 36.35 , Ta = 36.4
# Cycle = 729 , Ts = 36.4 , Ta = 36.45
# Cycle = 730 , Ts = 36.45 , Ta = 36.5
# Cycle = 731 , Ts = 36.5 , Ta = 36.55
# Cycle = 732 , Ts = 36.55 , Ta = 36.6
# Cycle = 733 , Ts = 36.6 , Ta = 36.65
# Cycle = 734 , Ts = 36.65 , Ta = 36.7
# Cycle = 735 , Ts = 36.7 , Ta = 36.75
# Cycle = 736 , Ts = 36.75 , Ta = 36.8
# Cycle = 737 , Ts = 36.8 , Ta = 36.85
# Cycle = 738 , Ts = 36.85 , Ta = 36.9
# Cycle = 739 , Ts = 36.9 , Ta = 36.95
# Cycle = 740 , Ts = 36.95 , Ta = 37.0
# Cycle = 741 , Ts = 37.0 , Ta = 37.05
# Cycle = 742 , Ts = 37.05 , Ta = 37.1
# Cycle = 743 , Ts = 37.1 , Ta = 37.15
# Cycle = 744 , Ts = 37.15 , Ta = 37.2
# Cycle = 745 , Ts = 37.2 , Ta = 37.25
# Cycle = 746 , Ts = 37.25 , Ta = 37.3
# Cycle = 747 , Ts = 37.3 , Ta = 37.35
# Cycle = 748 , Ts = 37.35 , Ta = 37.4
# Cycle = 749 , Ts = 37.4 , Ta = 37.45
# Cycle = 750 , Ts = 37.45 , Ta = 37.5
# Cycle = 751 , Ts = 37.5 , Ta = 37.55
# Cycle = 752 , Ts = 37.55 , Ta = 37.6
# Cycle = 753 , Ts = 37.6 , Ta = 37.65
# Cycle = 754 , Ts = 37.65 , Ta = 37.7
# Cycle = 755 , Ts = 37.7 , Ta = 37.75
# Cycle = 756 , Ts = 37.75 , Ta = 37.8
# Cycle = 757 , Ts = 37.8 , Ta = 37.85
# Cycle = 758 , Ts = 37.85 , Ta = 37.9
# Cycle = 759 , Ts = 37.9 , Ta = 37.95
# Cycle = 760 , Ts = 37.95 , Ta = 38.0
# Cycle = 761 , Ts = 38.0 , Ta = 38.05
# Cycle = 762 , Ts = 38.05 , Ta = 38.1
# Cycle = 763 , Ts = 38.1 , Ta = 38.15
# Cycle = 764 , Ts = 38.15 , Ta = 38.2
# Cycle = 765 , Ts = 38.2 , Ta = 38.25
# Cycle = 766 , Ts = 38.25 , Ta = 38.3
# Cycle = 767 , Ts = 38.3 , Ta = 38.35
# Cycle = 768 , Ts = 38.35 , Ta = 38.4
# Cycle = 769 , Ts = 38.4 , Ta = 38.45
# Cycle = 770 , Ts = 38.45 , Ta = 38.5
# Cycle = 771 , Ts = 38.5 , Ta = 38.55
# Cycle = 772 , Ts = 38.55 , Ta = 38.6
# Cycle = 773 , Ts = 38.6 , Ta = 38.65
# Cycle = 774 , Ts = 38.65 , Ta = 38.7
# Cycle = 775 , Ts = 38.7 , Ta = 38.75
# Cycle = 776 , Ts = 38.75 , Ta = 38.8
# Cycle = 777 , Ts = 38.8 , Ta = 38.85
# Cycle = 778 , Ts = 38.85 , Ta = 38.9
# Cycle = 779 , Ts = 38.9 , Ta = 38.95
# Cycle = 780 , Ts = 38.95 , Ta = 39.0
# Cycle = 781 , Ts = 39.0 , Ta = 39.05
# Cycle = 782 , Ts = 39.05 , Ta = 39.1
# Cycle = 783 , Ts = 39.1 , Ta = 39.15
# Cycle = 784 , Ts = 39.15 , Ta = 39.2
# Cycle = 785 , Ts = 39.2 , Ta = 39.25
# Cycle = 786 , Ts = 39.25 , Ta = 39.3
# Cycle = 787 , Ts = 39.3 , Ta = 39.35
# Cycle = 788 , Ts = 39.35 , Ta = 39.4
# Cycle = 789 , Ts = 39.4 , Ta = 39.45
# Cycle = 790 , Ts = 39.45 , Ta = 39.5
# Cycle = 791 , Ts = 39.5 , Ta = 39.55
# Cycle = 792 , Ts = 39.55 , Ta = 39.6
# Cycle = 793 , Ts = 39.6 , Ta = 39.65
# Cycle = 794 , Ts = 39.65 , Ta = 39.7
# Cycle = 795 , Ts = 39.7 , Ta = 39.75
# Cycle = 796 , Ts = 39.75 , Ta = 39.8
# Cycle = 797 , Ts = 39.8 , Ta = 39.85
# Cycle = 798 , Ts = 39.85 , Ta = 39.9
# Cycle = 799 , Ts = 39.9 , Ta = 39.95
# Cycle = 800 , Ts = 39.95 , Ta = 40.0

# %%
plt.plot(x_12_save[:,0]-x_b_save[:,0], label ="x_12-x_b" )
#plt.plot(x_12_save[:,0], label = "x_12")
plt.ylim(-0.5,0.5)
plt.legend(loc="upper left")
plt.title("x_b and x_12")
plt.show()

# %%
print(np.std(x_12_save[10:799,0]-x_b_save[10:799,0]))
# Out:
# 0.15995120397092336

# %%
print(np.std(x_24_save[10:799,0]-x_b_save[10:799,0]))
# Out:
# 0.3007909376194421

# %%
j = 0
nmc_24 = np.zeros((40,40))
nmc_12 = np.zeros((40,40))
nmc_1224 = np.zeros((40,40))

for i in range(10,799):
    j=j+1
    #print()
    nmc_12_i = np.reshape(x_12_save[i,:]-x_b_save[i,:],(40,1))
    nmc_12 = nmc_12 + np.matmul(nmc_12_i,np.transpose(nmc_12_i))
    nmc_24_i = np.reshape(x_24_save[i,:]-x_b_save[i,:],(40,1))
    nmc_24 = nmc_24 + np.matmul(nmc_24_i,np.transpose(nmc_24_i))
    nmc_1224_i = np.reshape(x_24_save[i,:]-x_12_save[i,:],(40,1))
    nmc_1224 = nmc_1224 + np.matmul(nmc_1224_i,np.transpose(nmc_1224_i))

# %%
B_12 = nmc_12/j*5
print(np.sum(B_12[B_12>0.07]/B_12[B_12>0.07].size))
print(B_12[B_12>0.07].size)

plt.imshow(B_12)
plt.colorbar()
plt.show()

B_24 = nmc_24/j*2.5
print(np.sum(B_24[B_24>0.07]/B_24[B_24>0.07].size))
#print(B_24[B_24>0.07].size)

plt.imshow(B_24)
plt.colorbar()
plt.show()

B_1224 = nmc_1224/j*5
print(np.sum(B_1224[B_1224>0.07]/B_1224[B_1224>0.07].size))
print(B_1224[B_1224>0.07].size)

plt.imshow(B_1224)
plt.colorbar()
plt.show()
print(np.std(B_1224[B_1224<0.07]))

B_1224_mask = B_1224 < 0.012 
B_1224_masked = ma.masked_array(B_1224, B_1224_mask)

plt.imshow(B_1224_masked)
plt.colorbar()
plt.show()
# Out:
# 0.14706251284042798
# 40
# 0.22174112802324397
# 52
# 0.25455499630447737
# 40
# 0.022946447635198

# %%
B_12_0 = 0
B_12_1 = 0
B_12_2 = 0
B_12_3 = 0
k=0
for i in range(1):
    for j in range(40):
        i=j
        B_12_0= B_12_0 + B_12[i][j]
        if j+1<40:
            i=j+1
            B_12_1 = B_12_1 + B_12[i][j]
            k=k+1
            
        else:
            i=j+1
            B_12_1 = B_12_1 + B_12[i-40][j]
            k=k+1
            
        if j-1>-1:
            i=j-1 
            B_12_1 = B_12_1 + B_12[i][j]
            k=k+1
        else:
            i=j-1 
            B_12_1 = B_12_1 + B_12[i+40][j]
            k=k+1
            
        if j+1<40 and j+2<40:
            i=j+2
            B_12_2 = B_12_2 + B_12[i][j]
            k=k+1
        else:
            i=j+2
            B_12_2 = B_12_2 + B_12[i-40][j]
            k=k+1
        if j-1>-1 and j-2>-1:
            i=j-2 
            B_12_2 = B_12_2 + B_12[i][j]
            k=k+1
        else:
            i=j-2 
            B_12_2 = B_12_2 + B_12[i+40][j]
            k=k+1
            
        if j+1<40 and j+2<40 and j+3<40:
            i=j+3
            B_12_3 = B_12_3 + B_12[i][j]
            k=k+1
        else:
            i=j+3
            B_12_3 = B_12_3 + B_12[i-40][j]
            k=k+1
        if j-1>-1 and j-2>-1 and j-3>-1:
            i=j-3
            B_12_3 = B_12_3 + B_12[i][j]
            k=k+1
        else:
            i=j-3 
            B_12_3 = B_12_3 + B_12[i+40][j]
            k=k+1
        
print(B_12_0/40)
print(B_12_1/80)
print(B_12_2/80)
print(B_12_3/80)
print(k)
# Out:
# 0.147062512840428
# 0.021930316499863843
# -0.017029211292945316
# 0.002185539492397991
# 240

# %%
#np.savetxt('B_12_raw.txt', B_12)
#np.savetxt('B_24_raw.txt', B_24)
#np.savetxt('B_1224_raw.txt', B_1224)
